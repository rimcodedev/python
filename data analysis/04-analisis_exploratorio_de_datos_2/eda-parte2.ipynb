# %% [markdown]
# # **ANÁLISIS EXPLORATORIO DE DATOS PARTE 2**
#
# 1. Tipos de datos
#
# 2. Manejando valores vacíos
#
# 3. Renombramiento columnas e índices
#
# 4. Combinando dataframes
#
# 5. Manejando fechas
#
# <img src="../imgs/foto-dia-03.jpg" width="500px" height="300px">

# %% [markdown]
# En esta clase vamos a trabajar con el dataset de canciones en Spotify en 2023, ejecuta la siguiente celda para ver las columnas del dataframe.

# %%
import pandas as pd

spotify = pd.read_csv('datasets/spotify-2023.csv', encoding='latin-1 ')
spotify.shape
spotify.head()
spotify.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# 25%              875.000000           0.000000           13.000000
# 50%             2224.000000           3.000000           34.000000
# 75%             5542.000000          16.000000           88.000000
# max            52898.000000         147.000000          672.000000
#
#        in_apple_charts  in_deezer_charts         bpm  danceability_%  \
# count       953.000000        953.000000  953.000000       953.00000
# mean         51.908709          2.666317  122.540399        66.96957
# std          50.630241          6.035599   28.057802        14.63061
# min           0.000000          0.000000   65.000000        23.00000
# 25%           7.000000          0.000000  100.000000        57.00000
# 50%          38.000000          0.000000  121.000000        69.00000
# 75%          87.000000          2.000000  140.000000        78.00000
# max         275.000000         58.000000  206.000000        96.00000
#
#         valence_%    energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# count  953.000000  953.000000      953.000000          953.000000  953.000000
# mean    51.431270   64.279119       27.057712            1.581322   18.213012
# std     23.480632   16.550526       25.996077            8.409800   13.711223
# min      4.000000    9.000000        0.000000            0.000000    3.000000
# 25%     32.000000   53.000000        6.000000            0.000000   10.000000
# 50%     51.000000   66.000000       18.000000            0.000000   12.000000
# 75%     70.000000   77.000000       43.000000            0.000000   24.000000
# max     97.000000   97.000000       97.000000           91.000000   97.000000
#
#        speechiness_%
# count     953.000000
# mean       10.131165
# std         9.912888
# min         2.000000
# 25%         4.000000
# 50%         6.000000
# 75%        11.000000
# max        64.000000

# %% [markdown]
# ### **1. Tipos de datos**

# %% [markdown]
# El tipo de datos de una columna en un DataFrame o una Serie se conoce como **dtype**.
#
# Puedes utilizar la propiedad dtype para obtener el tipo de una columna específica. Por ejemplo, podemos obtener el dtype de la columna precio en el DataFrame revisiones:

# %%
spotify['artist_count'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Alternativamente, la propiedad dtypes devuelve el dtype de cada columna del DataFrame:

# %%
spotify.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %% [markdown]
# Los tipos de datos nos dicen algo sobre cómo pandas está almacenando los datos internamente. float64 significa que está usando un número de coma flotante de 64 bits; int64 significa un entero de tamaño similar, y así sucesivamente.
#
# Una peculiaridad a tener en cuenta (y que se muestra muy claramente aquí) es que las columnas que consisten enteramente en cadenas no tienen su propio tipo; en su lugar se les da el tipo de objeto.
#
# Es posible convertir una columna de un tipo en otro siempre que dicha conversión tenga sentido utilizando la función astype(). Por ejemplo, podemos transformar la columna de `artist_count` de su actual tipo de datos int64 a un tipo de datos float64:

# %%
spotify['artist_count'].astype('float64')
# Out:
# 0      2.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 948    1.0
# 949    1.0
# 950    2.0
# 951    3.0
# 952    1.0
# Name: artist_count, Length: 953, dtype: float64

# %% [markdown]
# Un índice DataFrame o Series también tiene su propio dtype:

# %%
spotify.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### **2. Manejando valores vacíos**

# %% [markdown]
# Los valores que faltan en los registros reciben el valor NaN, abreviatura de "Not a Number" (no es un número). Por razones técnicas estos valores NaN son siempre del tipo float64.
#
# Pandas proporciona algunos métodos específicos para datos perdidos. Para seleccionar registros NaN se puede utilizar pd.isnull() (o su compañera pd.notnull()). Esto está pensado para ser usado así:

# %%
spotify.loc[spotify['key'].isnull()].shape
# Out:
# (95, 24)

# %% [markdown]
# Para saber que columnas tienen valores nulos dentro de nuestro dataframe podemos utilizar el siguiente código que nos dice el porcentaje de valores nulos para cada columna.

# %%
porcentaje_nulos_por_columna = (spotify.isnull().sum() / len(spotify)) * 100
porcentaje_nulos_por_columna
# Out:
# track_name              0.00000
# artist(s)_name          0.00000
# artist_count            0.00000
# released_year           0.00000
# released_month          0.00000
# released_day            0.00000
# in_spotify_playlists    0.00000
# in_spotify_charts       0.00000
# streams                 0.00000
# in_apple_playlists      0.00000
# in_apple_charts         0.00000
# in_deezer_playlists     0.00000
# in_deezer_charts        0.00000
# in_shazam_charts        5.24659
# bpm                     0.00000
# key                     9.96852
# mode                    0.00000
# danceability_%          0.00000
# valence_%               0.00000
# energy_%                0.00000
# acousticness_%          0.00000
# instrumentalness_%      0.00000
# liveness_%              0.00000
# speechiness_%           0.00000
# dtype: float64

# %% [markdown]
# Reemplazar valores NaN es una operación común. Pandas proporciona un método realmente práctico para este problema: `fillna()`.
#
# fillna() proporciona unas cuantas estrategias diferentes para mitigar tales datos. Por ejemplo, podemos simplemente reemplazar cada NaN por un "Desconocido":

# %%
spotify['key'] = spotify['key'].fillna('Unknown')
spotify['key'].value_counts()
# Out:
# key
# C#         120
# G           96
# Unknown     95
# G#          91
# F           89
# B           81
# D           81
# A           75
# F#          73
# E           62
# A#          57
# D#          33
# Name: count, dtype: int64

# %% [markdown]
# O podemos rellenar cada valor que falte con el primer valor no nulo que aparezca en algún momento después del registro dado en la base de datos. Esto se conoce como estrategia de relleno.
#
# También podemos tener un valor no nulo que queramos sustituir. Por ejemplo, supongamos que desde que se publicó este conjunto de datos, Bad Bunny ha cambiado su nombre artístico a Good Bunny, pues esto lo podríamos reflejar así.

# %%
spotify['artist(s)_name'] = spotify['artist(s)_name'].replace('Bad Bunny', 'Good Bunny')
spotify.loc[spotify['artist(s)_name'] == 'Good Bunny']
# Out:
#                track_name artist(s)_name  artist_count  released_year  \
# 4          WHERE SHE GOES     Good Bunny             1           2023
# 192     Titi Me Preguntï¿     Good Bunny             1           2022
# 239                Efecto     Good Bunny             1           2022
# 362              Neverita     Good Bunny             1           2022
# 377           Moscow Mule     Good Bunny             1           2022
# 422              Yonaguni     Good Bunny             1           2021
# 676           A Tu Merced     Good Bunny             1           2020
# 716               La Zona     Good Bunny             1           2020
# 766  Despuï¿½ï¿½s de la P     Good Bunny             1           2022
# 767             Un Ratito     Good Bunny             1           2022
# 770      Yo No Soy Celoso     Good Bunny             1           2022
# 773  Me Fui de Vacaciones     Good Bunny             1           2022
# 778            Dos Mil 16     Good Bunny             1           2022
# 781               Un Coco     Good Bunny             1           2022
# 784              Aguacero     Good Bunny             1           2022
# 786      Un Verano Sin Ti     Good Bunny             1           2022
# 788   Ensï¿½ï¿½ï¿½ï¿½ame      Good Bunny             1           2022
# 789            El Apagï¿½     Good Bunny             1           2022
# 792                Agosto     Good Bunny             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 4                 5            18                  3133                 50
# 192               5             6                  9037                 42
# 239               5             6                  4004                 33
# 362               5             6                  2590                 30
# 377               5             6                  4572                 33
# 422               6             4                  9644                 28
# 676               2            29                  4214                 11
# 716               2            29                  1188                  0
# 766               5             6                  2229                  0
# 767               5             6                  1112                  6
# 770               5             6                  1179                  0
# 773               5             6                  1443                  0
# 778               5             6                   892                  3
# 781               5             6                  1029                 28
# 784               5             6                   829                  0
# 786               5             6                  1004                  1
# 788               5             6                  1112                  3
# 789               5             6                  1209                  0
# 792               5             6                   897                  0
#
#         streams  in_apple_playlists  ...  bpm      key   mode danceability_%  \
# 4     303236322                  84  ...  144        A  Minor             65
# 192  1264310836                 124  ...  107        F  Minor             65
# 239  1047480053                  34  ...   98        G  Minor             80
# 362   671365962                  20  ...  122       A#  Major             88
# 377   909001996                  74  ...  100        F  Minor             80
# 422  1260594497                 120  ...  180       C#  Major             64
# 676   685071800                  21  ...   92  Unknown  Major             86
# 716   312622938                  13  ...   94       C#  Minor             76
# 766   461558540                  27  ...   78        F  Major             56
# 767   417230415                   7  ...   93  Unknown  Minor             79
# 770   313113297                   7  ...  142  Unknown  Major             87
# 773   305650299                   9  ...   85       A#  Major             71
# 778   338422004                  10  ...  130       C#  Major             82
# 781   403231558                   5  ...  152        B  Major             84
# 784   283359161                   4  ...  121       F#  Minor             86
# 786   283332261                   8  ...  188        F  Minor             50
# 788   279737940                   7  ...  105       G#  Major             81
# 789   212351890                   9  ...  118       G#  Major             63
# 792   246127838                   6  ...  115       C#  Minor             85
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 4           23       80             14                  63          11
# 192         19       72             10                   0          13
# 239         23       48             14                   0           6
# 362         43       50              7                   0          14
# 377         29       67             29                   0          12
# 422         44       65             28                   0          14
# 676         89       79             17                   0          11
# 716         81       80             20                   0          25
# 766         61       90             36                   0          18
# 767         22       55             31                   0          12
# 770         93       59             28                   0          17
# 773         43       65             23                   0           9
# 778         50       67             12                   0          13
# 781         74       69             21                   0          18
# 784         67       65             42                   0          35
# 786         41       50             69                   0          12
# 788         77       79             19                   0          47
# 789         60       70              5                   0           9
# 792         72       58              9                   0          49
#
#      speechiness_%
# 4                6
# 192             25
# 239              5
# 362              5
# 377              3
# 422             12
# 676              6
# 716              4
# 766             31
# 767              5
# 770              5
# 773              5
# 778              5
# 781              6
# 784              7
# 786              6
# 788              8
# 789             31
# 792             12
#
# [19 rows x 24 columns]

# %% [markdown]
# ### **3. Renombrando columnas e índices**

# %% [markdown]
# A menudo los datos nos llegan con nombres de columnas, índices u otras convenciones de nomenclatura con las que no estamos satisfechos. Para eso tenemos las funciones `rename` y `rename_axis`

# %% [markdown]
# La primera función rename(), permite cambiar los nombres de índices y/o columnas. Por ejemplo, para cambiar la columna nombre de artistas de nuestro conjunto de datos, haríamos:

# %%
spotify.rename(columns={'artist(s)_name' : 'artists_name'})
# Out:
#                               track_name        artists_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES          Good Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %% [markdown]
# `rename()` permite renombrar valores de índice o columna especificando un parámetro de palabra clave de índice o columna, respectivamente. Admite varios formatos de entrada, pero normalmente el más conveniente es un diccionario de Python. Un ejemplo que lo utiliza para renombrar algunos elementos del índice es el siguiente:

# %%
spotify.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#                                       track_name      artist(s)_name  \
# firstEntry   Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# secondEntry                                 LALA         Myke Towers
# 2                                        vampire      Olivia Rodrigo
# 3                                   Cruel Summer        Taylor Swift
# 4                                 WHERE SHE GOES          Good Bunny
# ...                                          ...                 ...
# 948                                 My Mind & Me        Selena Gomez
# 949                    Bigger Than The Whole Sky        Taylor Swift
# 950                         A Veces (feat. Feid)  Feid, Paulo Londra
# 951                                En La De Ella  Feid, Sech, Jhayco
# 952                                        Alone           Burna Boy
#
#              artist_count  released_year  released_month  released_day  \
# firstEntry              2           2023               7            14
# secondEntry             1           2023               3            23
# 2                       1           2023               6            30
# 3                       1           2019               8            23
# 4                       1           2023               5            18
# ...                   ...            ...             ...           ...
# 948                     1           2022              11             3
# 949                     1           2022              10            21
# 950                     2           2022              11             3
# 951                     3           2022              10            20
# 952                     1           2022              11             4
#
#              in_spotify_playlists  in_spotify_charts    streams  \
# firstEntry                    553                147  141381703
# secondEntry                  1474                 48  133716286
# 2                            1397                113  140003974
# 3                            7858                100  800840817
# 4                            3133                 50  303236322
# ...                           ...                ...        ...
# 948                           953                  0   91473363
# 949                          1180                  0  121871870
# 950                           573                  0   73513683
# 951                          1320                  0  133895612
# 952                           782                  2   96007391
#
#              in_apple_playlists  ...  bpm key   mode danceability_%  \
# firstEntry                   43  ...  125   B  Major             80
# secondEntry                  48  ...   92  C#  Major             71
# 2                            94  ...  138   F  Major             51
# 3                           116  ...  170   A  Major             55
# 4                            84  ...  144   A  Minor             65
# ...                         ...  ...  ...  ..    ...            ...
# 948                          61  ...  144   A  Major             60
# 949                           4  ...  166  F#  Major             42
# 950                           2  ...   92  C#  Major             80
# 951                          29  ...   97  C#  Major             82
# 952                          27  ...   90   E  Minor             61
#
#              valence_% energy_% acousticness_%  instrumentalness_%  \
# firstEntry          89       83             31                   0
# secondEntry         61       74              7                   0
# 2                   32       53             17                   0
# 3                   58       72             11                   0
# 4                   23       80             14                  63
# ...                ...      ...            ...                 ...
# 948                 24       39             57                   0
# 949                  7       24             83                   1
# 950                 81       67              4                   0
# 951                 67       77              8                   0
# 952                 32       67             15                   0
#
#              liveness_%  speechiness_%
# firstEntry            8              4
# secondEntry          10              4
# 2                    31              6
# 3                    11             15
# 4                    11              6
# ...                 ...            ...
# 948                   8              3
# 949                  12              6
# 950                   8              6
# 951                  12              5
# 952                  11              5
#
# [953 rows x 24 columns]

# %% [markdown]
# Probablemente renombrará columnas muy a menudo, pero renombrará valores de índice muy raramente. Para eso, `set_index()` suele ser más conveniente ya que normalmente renombraremos el índice con los valores de alguna columna.
#
# Tanto el índice de fila como el índice de columna pueden tener su propio atributo nombre. El método `rename_axis()` puede utilizarse para cambiar estos nombres. Por ejemplo:

# %%
spotify.rename_axis('canciones', axis='rows').rename_axis('nombre_columnas', axis='columns')
# Out:
# nombre_columnas                           track_name      artist(s)_name  \
# canciones
# 0                Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                               LALA         Myke Towers
# 2                                            vampire      Olivia Rodrigo
# 3                                       Cruel Summer        Taylor Swift
# 4                                     WHERE SHE GOES          Good Bunny
# ...                                              ...                 ...
# 948                                     My Mind & Me        Selena Gomez
# 949                        Bigger Than The Whole Sky        Taylor Swift
# 950                             A Veces (feat. Feid)  Feid, Paulo Londra
# 951                                    En La De Ella  Feid, Sech, Jhayco
# 952                                            Alone           Burna Boy
#
# nombre_columnas  artist_count  released_year  released_month  released_day  \
# canciones
# 0                           2           2023               7            14
# 1                           1           2023               3            23
# 2                           1           2023               6            30
# 3                           1           2019               8            23
# 4                           1           2023               5            18
# ...                       ...            ...             ...           ...
# 948                         1           2022              11             3
# 949                         1           2022              10            21
# 950                         2           2022              11             3
# 951                         3           2022              10            20
# 952                         1           2022              11             4
#
# nombre_columnas  in_spotify_playlists  in_spotify_charts    streams  \
# canciones
# 0                                 553                147  141381703
# 1                                1474                 48  133716286
# 2                                1397                113  140003974
# 3                                7858                100  800840817
# 4                                3133                 50  303236322
# ...                               ...                ...        ...
# 948                               953                  0   91473363
# 949                              1180                  0  121871870
# 950                               573                  0   73513683
# 951                              1320                  0  133895612
# 952                               782                  2   96007391
#
# nombre_columnas  in_apple_playlists  ...  bpm key   mode danceability_%  \
# canciones                            ...
# 0                                43  ...  125   B  Major             80
# 1                                48  ...   92  C#  Major             71
# 2                                94  ...  138   F  Major             51
# 3                               116  ...  170   A  Major             55
# 4                                84  ...  144   A  Minor             65
# ...                             ...  ...  ...  ..    ...            ...
# 948                              61  ...  144   A  Major             60
# 949                               4  ...  166  F#  Major             42
# 950                               2  ...   92  C#  Major             80
# 951                              29  ...   97  C#  Major             82
# 952                              27  ...   90   E  Minor             61
#
# nombre_columnas  valence_% energy_% acousticness_%  instrumentalness_%  \
# canciones
# 0                       89       83             31                   0
# 1                       61       74              7                   0
# 2                       32       53             17                   0
# 3                       58       72             11                   0
# 4                       23       80             14                  63
# ...                    ...      ...            ...                 ...
# 948                     24       39             57                   0
# 949                      7       24             83                   1
# 950                     81       67              4                   0
# 951                     67       77              8                   0
# 952                     32       67             15                   0
#
# nombre_columnas  liveness_%  speechiness_%
# canciones
# 0                         8              4
# 1                        10              4
# 2                        31              6
# 3                        11             15
# 4                        11              6
# ...                     ...            ...
# 948                       8              3
# 949                      12              6
# 950                       8              6
# 951                      12              5
# 952                      11              5
#
# [953 rows x 24 columns]

# %% [markdown]
# ### **4. Combinando dataframes**

# %% [markdown]
# Al realizar operaciones en un conjunto de datos, a veces necesitaremos combinar diferentes DataFrames y/o Series de formas no sencillas. Pandas tiene tres métodos básicos para hacer esto. En orden de complejidad creciente, son `concat()`, `join()` y `merge()`. La mayor parte de lo que puede hacer merge() también se puede hacer de forma más sencilla con join(), por lo que la omitiremos y nos centraremos en las dos primeras funciones.
#
# El método de combinación más sencillo es concat(). Dada una lista de elementos, esta función los unirá a lo largo de un eje.
#
# Esto es útil cuando tenemos datos en diferentes objetos DataFrame o Series pero que tienen los mismos campos (columnas). Un ejemplo, es el que vamos a ver ahora con el conjunto de datos YouTube Videos, que divide los datos en función del país de origen (por ejemplo, Canadá y USA, en este ejemplo). Si queremos estudiar varios países a la vez, podemos utilizar concat() para agruparlos.

# %%
canadian_youtube = pd.read_csv('./datasets/CAvideos.csv')
usa_youtube = pd.read_csv('./datasets/USvideos.csv')

canadian_youtube.head()
usa_youtube.head()

union_youtube = pd.concat([canadian_youtube, usa_youtube])
union_youtube.shape
# Out:
# (81830, 16)

# %% [markdown]
# El combinador intermedio en términos de complejidad es `join()`. join() permite combinar diferentes objetos DataFrame que tienen un índice en común. Por ejemplo, para obtener los vídeos que fueron tendencia el mismo día en Canadá y en USA, podemos hacer lo siguiente:

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = usa_youtube.set_index(['title', 'trending_date'])

inner_join = left.join(right, lsuffix='_CAN', rsuffix='_USA', how='inner')

inner_join.shape

inner_join.head()
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       5qpjK5DgCt4
# I Dare You: GOING BALD!?                           17.14.11       d380meD0W0M
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       2Vv-BfVoq4g
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11       2kyS6SvSYSE
#
#                                                                  channel_title_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11             EminemVEVO
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11           Rudy Mancuso
# I Dare You: GOING BALD!?                           17.14.11               nigahiga
# Ed Sheeran - Perfect (Official Music Video)        17.14.11             Ed Sheeran
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11           CaseyNeistat
#
#                                                                   category_id_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                    10
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11                    23
# I Dare You: GOING BALD!?                           17.14.11                    24
# Ed Sheeran - Perfect (Official Music Video)        17.14.11                    10
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                    22
#
#                                                                           publish_time_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       2017-11-10T17:00:03.000Z
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       2017-11-12T19:05:24.000Z
# I Dare You: GOING BALD!?                           17.14.11       2017-11-12T18:01:41.000Z
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       2017-11-09T11:04:14.000Z
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11       2017-11-13T17:13:01.000Z
#
#                                                                                                            tags_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       racist superman|"rudy"|"mancuso"|"king"|"bach"...
# I Dare You: GOING BALD!?                           17.14.11       ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                                         SHANtell martin
#
#                                                                   views_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11        17158579
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11         3191434
# I Dare You: GOING BALD!?                           17.14.11         2095828
# Ed Sheeran - Perfect (Official Music Video)        17.14.11        33523622
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11          748374
#
#                                                                   likes_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11          787425
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11          146035
# I Dare You: GOING BALD!?                           17.14.11          132239
# Ed Sheeran - Perfect (Official Music Video)        17.14.11         1634130
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11           57534
#
#                                                                   dislikes_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11              43420
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11               5339
# I Dare You: GOING BALD!?                           17.14.11               1989
# Ed Sheeran - Perfect (Official Music Video)        17.14.11              21082
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11               2967
#
#                                                                   comment_count_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                  125882
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11                    8181
# I Dare You: GOING BALD!?                           17.14.11                   17518
# Ed Sheeran - Perfect (Official Music Video)        17.14.11                   85067
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                   15959
#
#                                                                                               thumbnail_link_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# I Dare You: GOING BALD!?                           17.14.11       https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11       https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
#
#                                                                   ...  \
# title                                              trending_date  ...
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       ...
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       ...
# I Dare You: GOING BALD!?                           17.14.11       ...
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       ...
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11       ...
#
#                                                                                                            tags_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       racist superman|"rudy"|"mancuso"|"king"|"bach"...
# I Dare You: GOING BALD!?                           17.14.11       ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                                         SHANtell martin
#
#                                                                   views_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11        17158531
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11         3191434
# I Dare You: GOING BALD!?                           17.14.11         2095731
# Ed Sheeran - Perfect (Official Music Video)        17.14.11        33523622
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11          748374
#
#                                                                   likes_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11          787419
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11          146033
# I Dare You: GOING BALD!?                           17.14.11          132235
# Ed Sheeran - Perfect (Official Music Video)        17.14.11         1634124
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11           57527
#
#                                                                  dislikes_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11             43420
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11              5339
# I Dare You: GOING BALD!?                           17.14.11              1989
# Ed Sheeran - Perfect (Official Music Video)        17.14.11             21082
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11              2966
#
#                                                                  comment_count_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                 125882
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11                   8181
# I Dare You: GOING BALD!?                           17.14.11                  17518
# Ed Sheeran - Perfect (Official Music Video)        17.14.11                  85067
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                  15954
#
#                                                                                               thumbnail_link_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# I Dare You: GOING BALD!?                           17.14.11       https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11       https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
#
#                                                                   comments_disabled_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                       False
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11                       False
# I Dare You: GOING BALD!?                           17.14.11                       False
# Ed Sheeran - Perfect (Official Music Video)        17.14.11                       False
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                       False
#
#                                                                  ratings_disabled_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                     False
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11                     False
# I Dare You: GOING BALD!?                           17.14.11                     False
# Ed Sheeran - Perfect (Official Music Video)        17.14.11                     False
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                     False
#
#                                                                  video_error_or_removed_USA  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11                           False
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11                           False
# I Dare You: GOING BALD!?                           17.14.11                           False
# Ed Sheeran - Perfect (Official Music Video)        17.14.11                           False
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11                           False
#
#                                                                                                     description_USA
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       Eminem's new track Walk on Water ft. Beyoncé i...
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# I Dare You: GOING BALD!?                           17.14.11       I know it's been a while since we did this sho...
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       🎧: https://ad.gt/yt-perfect\n💰: https://atlant...
# WE WANT TO TALK ABOUT OUR MARRIAGE                 17.14.11       SHANTELL'S CHANNEL - https://www.youtube.com/s...
#
# [5 rows x 28 columns]

# %% [markdown]
# Los parámetros lsuffix y rsuffix son necesarios aquí porque los datos tienen los mismos nombres de columna en los conjuntos de datos británicos y estado unidenses. Si no fuera así (porque, por ejemplo, les hubiéramos cambiado el nombre de antemano) no los necesitaríamos.

# %% [markdown]
# ### **5. Manejando fechas**

# %% [markdown]
# En el análisis de datos, a menudo necesitamos trabajar con datos de fecha y hora. Pandas proporciona numerosas funciones y métodos para manejar eficazmente datos de fecha y hora. A continuación, vamos a ver algunas de las funciones más comunes para el manejo de fechas en Pandas:
#
# La función `pd.to_datetime()` se utiliza para convertir una columna a un tipo de dato de fecha y hora. Esto es útil cuando los datos de fecha y hora están en formato de cadena y necesitas convertirlos a un formato reconocido por Pandas.

# %%
canadian_youtube.head(5)
canadian_youtube.dtypes

canadian_youtube['publish_time'] = pd.to_datetime(canadian_youtube['publish_time'])
canadian_youtube['trending_date'] = pd.to_datetime(canadian_youtube['trending_date'], format='%y.%d.%m')

# %% [markdown]
# Es importante saber que podemos realizar extracciones de cierta parte de la fecha, como el mes o el año y también podemos realizar operaciones aritméticas para sumar o restar días, meses, etc...

# %%
# Extaccion de partes de una fecha
canadian_youtube['year_publish_time'] = canadian_youtube['publish_time'].dt.year

# Añadir dias a una fecha
canadian_youtube['trending_date_plus_seven_days'] = canadian_youtube['trending_date'] + pd.Timedelta(days=7)

# Restar meses a una fecha
canadian_youtube['trending_date_less_month'] = canadian_youtube['trending_date'] + pd.DateOffset(months=-1)
canadian_youtube['trending_date_plus_seven_days'] = canadian_youtube['trending_date'] + pd.DateOffset(days=7)

canadian_youtube.head(5)
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc    2017-11-14
# 1  0dBIkQ4Mz1M    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  d380meD0W0M    2017-11-14
# 4  2Vv-BfVoq4g    2017-11-14
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10 2017-11-10 17:00:03+00:00
# 1           23 2017-11-13 17:00:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-12 18:01:41+00:00
# 4           10 2017-11-09 11:04:14+00:00
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description  year_publish_time  \
# 0  Eminem's new track Walk on Water ft. Beyoncé i...               2017
# 1  STill got a lot of packages. Probably will las...               2017
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...               2017
# 3  I know it's been a while since we did this sho...               2017
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...               2017
#
#   trending_date_plus_seven_days trending_date_less_month
# 0                    2017-11-21               2017-10-14
# 1                    2017-11-21               2017-10-14
# 2                    2017-11-21               2017-10-14
# 3                    2017-11-21               2017-10-14
# 4                    2017-11-21               2017-10-14

# %% [markdown]
# Una vez que sabemos extraer ciertas partes de una fecha se nos abre una posibilidad a realizar estudios de agrupación y filtrado por estas partes de la fecha, en especial, esto es muy útil para utilizar el año.

# %%
canadian_youtube_2017 = canadian_youtube.loc[canadian_youtube['publish_time'].dt.year == 2017]
canadian_youtube_2017.head(5)

canadian_youtube.groupby(canadian_youtube['publish_time'].dt.year)['video_id'].describe()
# Out:
#               count unique          top freq
# publish_time
# 2008              5      2  rrkW65P-5sc    3
# 2009              1      1  lT47mzF3QVM    1
# 2010              3      1  zzjNCiCqiOs    3
# 2012              1      1  K3VQJAxut0w    1
# 2013              9      5  e_LpxldL8h4    3
# 2014              6      6  L1fwxUV6GJE    1
# 2015              7      6  SC-ki9DdMiw    2
# 2016             13      9  hHcInn9TmXs    2
# 2017           9900   5590  6ZfuNTqbHE8    8
# 2018          30936  18807  VYOjWnS4cMY    8
